# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
min_distances = np.loadtxt('min_distances.csv', delimiter=',')

# %%
sns.boxplot(min_distances)
# Out:
# <Axes: >

# %%
# take values lower than 4

min_distances = []

for dist in min_dists:
    if dist < 4:
        min_distances.append(dist)


min_distances = np.array(min_distances)

mean = min_distances.mean()
median = np.median(min_distances)
std_dev = min_distances.std()
print(std_dev)
# Out:
# 0.5473672311075438

# %%
sns.boxplot(min_distances)
# Out:
# <Axes: >

# %%
from scipy.stats import norm
ax = sns.histplot(min_distances)

plt.axvline(x=median, color='green', linewidth=1, label='median')

x = np.linspace(0, 4, 100)
y = norm.pdf(x, mean, std_dev)

y = y * 1800

ax.plot(x, y, label='gaussian curve', color="red", zorder=2)

plt.title("Histogram of distribution vs gaussian with mean and std_dev")
plt.legend()
plt.show()
